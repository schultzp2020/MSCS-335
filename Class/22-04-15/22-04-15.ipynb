# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('forSVD.csv', index_col=0)

# %%
df.describe()
# Out:
#                  x0            x1            x2            x3            x4  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       6.123427      4.007631      8.943256      7.949675      3.989244
# std        0.230945      0.144439      0.188897      0.184243      0.072134
# min        5.803439      3.724157      8.497358      7.522832      3.826672
# 25%        5.949510      3.901684      8.793845      7.840799      3.933653
# 50%        6.061249      4.008041      8.985518      7.960214      3.985604
# 75%        6.241173      4.100836      9.098860      8.096890      4.046255
# max        6.712875      4.326023      9.240064      8.261033      4.156214
#
#                  x5            x6            x7            x8            x9  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       7.057299      6.038597      4.903851      2.999120      1.969975
# ...

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<AxesSubplot:xlabel='x0', ylabel='x0'>,
#         <AxesSubplot:xlabel='x1', ylabel='x0'>,
#         <AxesSubplot:xlabel='x2', ylabel='x0'>,
#         <AxesSubplot:xlabel='x3', ylabel='x0'>,
#         <AxesSubplot:xlabel='x4', ylabel='x0'>,
#         <AxesSubplot:xlabel='x5', ylabel='x0'>,
#         <AxesSubplot:xlabel='x6', ylabel='x0'>,
#         <AxesSubplot:xlabel='x7', ylabel='x0'>,
#         <AxesSubplot:xlabel='x8', ylabel='x0'>,
#         <AxesSubplot:xlabel='x9', ylabel='x0'>,
#         <AxesSubplot:xlabel='x10', ylabel='x0'>,
#         <AxesSubplot:xlabel='x11', ylabel='x0'>,
#         <AxesSubplot:xlabel='x12', ylabel='x0'>,
#         <AxesSubplot:xlabel='x13', ylabel='x0'>,
#         <AxesSubplot:xlabel='x14', ylabel='x0'>,
#         <AxesSubplot:xlabel='x15', ylabel='x0'>,
#         <AxesSubplot:xlabel='x16', ylabel='x0'>,
#         <AxesSubplot:xlabel='x17', ylabel='x0'>,
#         <AxesSubplot:xlabel='x18', ylabel='x0'>,
# ...

# %%
pca = PCA()
pca.fit(df)
# Out:
# PCA()

# %%
for s in pca.singular_values_:
  print(s/pca.singular_values_[0])
# Out:
# 1.0
# 0.7474222543431231
# 0.40854135589990775
# 0.014362150892327489
# 0.014175909792253194
# 0.014136366499237028
# 0.014102409034949737
# 0.014026759869814843
# 0.013956941703669559
# 0.013925479926445416
# 0.01383579447918976
# 0.013818513424471861
# 0.013767482099535948
# 0.0137242171204317
# 0.013685022003967368
# 0.01365407181359766
# 0.01359416393623131
# 0.013577747168339186
# 0.013520061221912967
# 0.01347335313166604
# 0.013451627985674525
# 0.013420900134835715
# 0.013396862074573874
# 0.013302762054125788
# 0.01327479302795072
# 0.013245859115642742
# 0.013235644850107729
# 0.013134618184297661
# 0.013031227929816135
# 0.012975013218211059

# %%
for ev in pca.explained_variance_:
  print(ev*100)
# Out:
# 53.78744179875454
# 30.047817900385876
# 8.977448884419909
# 0.011094809752585005
# 0.010808931660825468
# 0.010748713358203876
# 0.01069713565448872
# 0.010582678767564937
# 0.010477590438361915
# 0.010430406451866103
# 0.010296487430697072
# 0.010270782648492195
# 0.01019506338261063
# 0.010131087104458893
# 0.010073302808240214
# 0.01002779055585362
# 0.009939988798302612
# 0.009915995567472644
# 0.00983191704348364
# 0.009764101254146782
# 0.009732638336022966
# 0.009688224160846437
# 0.009653550248709624
# 0.00951841278788227
# 0.00947842998264396
# 0.009437156392309406
# 0.009422607474872053
# 0.009279312364574419
# 0.009133801548515182
# 0.00905516789374987

# %%
pca = PCA(n_components=3)
pca.fit(df)
# Out:
# PCA(n_components=3)

# %%
for s in pca.singular_values_:
  print(s/pca.singular_values_[0])
# Out:
# 1.0
# 0.7474222543431227
# 0.4085413558999077

# %%
for ev in pca.explained_variance_:
  print(ev*100)
# Out:
# 53.78744179875456
# 30.047817900385855
# 8.97744888441991

# %%
g = pd.DataFrame(pca.transform(df), columns=[f'pc{i}' for i in range(pca.n_components)])
g.shape
# Out:
# (10000, 3)

# %%
g
# Out:
#            pc0       pc1       pc2
# 0     0.894918  0.495119 -0.316238
# 1     0.305697  0.874895  0.145889
# 2    -1.045095 -0.035800 -0.203534
# 3     0.894715  0.475282 -0.320450
# 4    -0.260663 -0.702788 -0.031802
# ...        ...       ...       ...
# 9995  0.303091  0.138292 -0.333145
# 9996  0.271156 -0.700901  0.235193
# 9997 -0.408633  0.911405  0.643058
# 9998  0.288889  0.696079 -0.046174
# 9999 -0.695273 -0.480651 -0.305167
#
# [10000 rows x 3 columns]

# %%
pd.plotting.scatter_matrix(g)
# Out:
# array([[<AxesSubplot:xlabel='pc0', ylabel='pc0'>,
#         <AxesSubplot:xlabel='pc1', ylabel='pc0'>,
#         <AxesSubplot:xlabel='pc2', ylabel='pc0'>],
#        [<AxesSubplot:xlabel='pc0', ylabel='pc1'>,
#         <AxesSubplot:xlabel='pc1', ylabel='pc1'>,
#         <AxesSubplot:xlabel='pc2', ylabel='pc1'>],
#        [<AxesSubplot:xlabel='pc0', ylabel='pc2'>,
#         <AxesSubplot:xlabel='pc1', ylabel='pc2'>,
#         <AxesSubplot:xlabel='pc2', ylabel='pc2'>]], dtype=object)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(g['pc0'], g['pc1'], g['pc2'])
ax.view_init(270, 0)
