# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Auto.csv', na_values="?")

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %%
df = df.dropna(subset=['horsepower'])

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
pd.plotting.scatter_matrix(df, figsize=(15,15))
plt.plot()
# Out:
# []

# %% [markdown]
# ### Linear Regession
# $acceleration = m_1(mpg) + m_2(cylinders) + m_3(displacement) + +m_4(horsepower) + m_5(weight) + m_6(year)$
#
# - $mpg$: MPG can inversely relate to acceleration
# - $cylinders$: Cylinders can directly relate to acceleration
# - $displacement$: Displacement can inversely relate to acceleration
# - $horsepower$: Horsepower can directly relate to acceleration
# - $weight$: Weight can inversely relate to acceleration
# - $year$: Year can directly relate to acceleration

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(df[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'year']], df['acceleration'])
model.coef_
# Out:
# array([ 0.02123546, -0.15489662, -0.0081462 , -0.08571898,  0.00330677,
#        -0.05629916])

# %% [markdown]
# Below uses the average of each of the independent variables to predict the acceleration.

# %%
x = np.array([[23.515869, 5.458438, 193.532746, 104.469388, 2970.261965, 75.994962]])

model.predict(x)
# Out:
# /home/pschultz/anaconda3/envs/MSCS-basic/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15.52698744])
