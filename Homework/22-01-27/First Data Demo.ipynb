# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Auto.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 392       1            ford mustang gl
# 393       2                  vw pickup
# 394       1              dodge rampage
# 395       1                ford ranger
# 396       1                 chevy s-10
#
# [397 rows x 9 columns]

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(15,15))
plt.plot()
# Out:
# []

# %% [markdown]
# ### Linear Regession
# $acceleration = m_1(mpg) + m_2(cylinders) + m_3(displacement) + m_4(weight) + m_5(year)$
#
# - $mpg$: MPG can inversely relate to acceleration
# - $cylinders$: Cylinders can directly relate to acceleration
# - $displacement$: Displacement can inversely relate to acceleration
# - $weight$: Weight can inversely relate to acceleration
# - $year$: Year can directly relate to acceleration

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(df[['mpg', 'cylinders', 'displacement', 'weight', 'year']], df['acceleration'])
model.coef_
# Out:
# array([ 0.03687925,  0.12337039, -0.0318093 ,  0.00238231,  0.02088163])

# %% [markdown]
# Below uses the average of each of the independent variables to predict the acceleration.

# %%
x = np.array([[23.515869, 5.458438, 193.532746, 2970.261965, 75.994962]])

model.predict(x)
# Out:
# /home/pschultz/anaconda3/envs/MSCS-basic/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15.55566745])
